# %% [markdown]
# # JOBSHEET 13 - Artificial Neural Network (ANN) dan Evaluasi Classifier
#
# Nama: Diana Rahmawati <br>
# Kelas: TI - 3G <br>
# NIM: 2341720162

# %% [markdown]
# ### PRAKTIKUM 2

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4156 - loss: 2.3515
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4130 - loss: 1.9174
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3987 - loss: 1.6128
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3039 - loss: 1.6034
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3751 - loss: 1.3950
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2741 - loss: 1.3453
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2678 - loss: 1.2992
# Epoch 8/50
# ...

# %% [markdown]
# ### Tugas 2
#
# - Ubah jumlah neuron hidden layer.
# - Bandingkan akurasi dengan konfigurasi awal.

# %%
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


def build_and_train_model(neurons1, neurons2):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(neurons1, activation='relu', input_shape=(4,)),
        tf.keras.layers.Dense(neurons2, activation='relu'),
        tf.keras.layers.Dense(3, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=0)

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    return acc


# Coba tiga konfigurasi
acc_A = build_and_train_model(10, 8)   # baseline
acc_B = build_and_train_model(6, 4)
acc_C = build_and_train_model(16, 12)

print("=== Perbandingan Akurasi ===")
print(f"Konfigurasi A (10-8): {acc_A:.4f}")
print(f"Konfigurasi B (6-4):  {acc_B:.4f}")
print(f"Konfigurasi C (16-12): {acc_C:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# === Perbandingan Akurasi ===
# Konfigurasi A (10-8): 1.0000
# Konfigurasi B (6-4):  0.7000
# Konfigurasi C (16-12): 1.0000

# %%
def train_with_activation(activation):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(10, activation=activation, input_shape=(4,)),
        tf.keras.layers.Dense(8, activation=activation),
        tf.keras.layers.Dense(3, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=0)

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    return loss, acc


# Train dua model
loss_relu, acc_relu = train_with_activation('relu')
loss_sig, acc_sig   = train_with_activation('sigmoid')

print("=== Perbandingan ReLU vs Sigmoid ===")
print(f"ReLU    -> Loss: {loss_relu:.4f}, Akurasi: {acc_relu:.4f}")
print(f"Sigmoid -> Loss: {loss_sig:.4f}, Akurasi: {acc_sig:.4f}")
# Out:
# === Perbandingan ReLU vs Sigmoid ===
# ReLU    -> Loss: 0.3184, Akurasi: 0.9667
# Sigmoid -> Loss: 0.6925, Akurasi: 0.6000
